# %% [markdown]
# <a href="https://colab.research.google.com/github/chohayden/csci-166/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-cw98p35c
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-cw98p35c
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=c602c68f75bf347e26345949597e5c86581c7fbb3d77fbe41f6f45568ed7d9ef
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6ek6zzla/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.274311, train error 87.60,  test loss 2.269835, test error 86.57
# Epoch   100, train loss 1.852372, train error 70.30,  test loss 1.706945, test error 69.18
# Epoch   200, train loss 1.852605, train error 69.93,  test loss 1.705626, test error 69.00
# Epoch   300, train loss 1.847618, train error 69.45,  test loss 1.699960, test error 68.32
# Epoch   400, train loss 1.847221, train error 69.85,  test loss 1.700396, test error 68.50
# Epoch   500, train loss 1.847115, train error 70.20,  test loss 1.699287, test error 68.78
# Epoch   600, train loss 1.846633, train error 70.28,  test loss 1.693104, test error 68.45
# Epoch   700, train loss 1.845531, train error 70.28,  test loss 1.695824, test error 68.32
# Epoch   800, train loss 1.846434, train error 69.90,  test loss 1.696432, test error 67.82
# Epoch   900, train loss 1.844966, train error 70.03,  test loss 1.696939, test error 67.72
# Training model with   4 hidden variables
# Epoch     0, train loss 2.302785, train error 90.62,  test loss 2.295979, test error 90.32
# Epoch   100, train loss 1.843025, train error 69.55,  test loss 1.698770, test error 69.10
# Epoch   200, train loss 1.810879, train error 67.47,  test loss 1.663974, test error 66.07
# Epoch   300, train loss 1.800574, train error 67.28,  test loss 1.664138, test error 66.18
# Epoch   400, train loss 1.793667, train error 67.20,  test loss 1.666596, test error 66.05
# Epoch   500, train loss 1.791136, train error 66.88,  test loss 1.666169, test error 66.55
# Epoch   600, train loss 1.793932, train error 67.90,  test loss 1.684830, test error 67.00
# Epoch   700, train loss 1.786562, train error 66.97,  test loss 1.675270, test error 66.43
# Epoch   800, train loss 1.786187, train error 67.28,  test loss 1.691523, test error 66.97
# Epoch   900, train loss 1.784424, train error 67.10,  test loss 1.685114, test error 66.25
# Training model with   6 hidden variables
# Epoch     0, train loss 2.291590, train error 88.15,  test loss 2.290284, test error 87.35
# Epoch   100, train loss 1.706400, train error 60.40,  test loss 1.585252, test error 58.88
# Epoch   200, train loss 1.654817, train error 59.08,  test loss 1.501974, test error 56.75
# Epoch   300, train loss 1.635358, train error 58.35,  test loss 1.476581, test error 56.60
# Epoch   400, train loss 1.627262, train error 57.65,  test loss 1.464537, test error 55.67
# Epoch   500, train loss 1.625279, train error 57.72,  test loss 1.465450, test error 55.75
# Epoch   600, train loss 1.619480, train error 57.72,  test loss 1.467137, test error 55.67
# Epoch   700, train loss 1.622029, train error 57.40,  test loss 1.469882, test error 56.08
# Epoch   800, train loss 1.622756, train error 57.70,  test loss 1.467519, test error 55.70
# Epoch   900, train loss 1.610699, train error 56.83,  test loss 1.472262, test error 55.75
# Training model with   8 hidden variables
# Epoch     0, train loss 2.247675, train error 85.07,  test loss 2.237970, test error 85.35
# Epoch   100, train loss 1.606211, train error 56.53,  test loss 1.470646, test error 57.62
# Epoch   200, train loss 1.579189, train error 56.12,  test loss 1.465638, test error 56.33
# Epoch   300, train loss 1.565651, train error 55.08,  test loss 1.456977, test error 56.80
# Epoch   400, train loss 1.544819, train error 53.62,  test loss 1.444162, test error 56.30
# Epoch   500, train loss 1.534925, train error 53.38,  test loss 1.448890, test error 55.60
# Epoch   600, train loss 1.533131, train error 54.17,  test loss 1.449875, test error 55.70
# Epoch   700, train loss 1.517514, train error 53.12,  test loss 1.441170, test error 54.35
# Epoch   800, train loss 1.517592, train error 52.60,  test loss 1.438269, test error 54.75
# Epoch   900, train loss 1.520480, train error 53.20,  test loss 1.451505, test error 55.15
# Training model with  10 hidden variables
# Epoch     0, train loss 2.222248, train error 83.62,  test loss 2.203166, test error 82.75
# Epoch   100, train loss 1.538239, train error 53.78,  test loss 1.388956, test error 53.15
# Epoch   200, train loss 1.461398, train error 50.35,  test loss 1.337142, test error 50.50
# Epoch   300, train loss 1.439563, train error 49.90,  test loss 1.342660, test error 50.08
# Epoch   400, train loss 1.429547, train error 49.78,  test loss 1.351124, test error 49.75
# Epoch   500, train loss 1.427315, train error 49.83,  test loss 1.358641, test error 50.78
# Epoch   600, train loss 1.416035, train error 49.33,  test loss 1.366323, test error 50.78
# Epoch   700, train loss 1.420117, train error 49.45,  test loss 1.375080, test error 50.83
# Epoch   800, train loss 1.407132, train error 49.05,  test loss 1.375244, test error 51.17
# Epoch   900, train loss 1.400753, train error 48.17,  test loss 1.381284, test error 50.85
# Training model with  14 hidden variables
# Epoch     0, train loss 2.170651, train error 80.80,  test loss 2.127105, test error 80.10
# Epoch   100, train loss 1.417599, train error 48.17,  test loss 1.337385, test error 49.45
# Epoch   200, train loss 1.361883, train error 46.70,  test loss 1.338569, test error 50.38
# Epoch   300, train loss 1.334541, train error 45.80,  test loss 1.344753, test error 49.80
# Epoch   400, train loss 1.324070, train error 45.78,  test loss 1.373061, test error 50.72
# Epoch   500, train loss 1.307399, train error 45.08,  test loss 1.384711, test error 51.25
# Epoch   600, train loss 1.295355, train error 44.08,  test loss 1.407616, test error 51.08
# Epoch   700, train loss 1.291832, train error 44.00,  test loss 1.424409, test error 51.25
# Epoch   800, train loss 1.281422, train error 43.83,  test loss 1.463945, test error 52.10
# Epoch   900, train loss 1.277246, train error 44.17,  test loss 1.478288, test error 51.33
# Training model with  18 hidden variables
# Epoch     0, train loss 2.249832, train error 83.40,  test loss 2.231227, test error 82.50
# Epoch   100, train loss 1.340016, train error 44.03,  test loss 1.296052, test error 47.70
# Epoch   200, train loss 1.218826, train error 40.38,  test loss 1.285992, test error 45.95
# Epoch   300, train loss 1.171014, train error 38.62,  test loss 1.324938, test error 46.78
# Epoch   400, train loss 1.142608, train error 38.28,  test loss 1.392630, test error 47.85
# Epoch   500, train loss 1.129263, train error 38.22,  test loss 1.435190, test error 48.50
# Epoch   600, train loss 1.109264, train error 36.65,  test loss 1.440477, test error 48.50
# Epoch   700, train loss 1.111187, train error 36.72,  test loss 1.495123, test error 49.05
# Epoch   800, train loss 1.098745, train error 36.55,  test loss 1.524025, test error 49.15
# Epoch   900, train loss 1.097345, train error 36.85,  test loss 1.528331, test error 49.17
# Training model with  22 hidden variables
# Epoch     0, train loss 2.236783, train error 84.18,  test loss 2.233908, test error 83.97
# Epoch   100, train loss 1.241825, train error 41.40,  test loss 1.297896, test error 48.45
# Epoch   200, train loss 1.120618, train error 37.15,  test loss 1.359672, test error 48.78
# Epoch   300, train loss 1.058371, train error 35.43,  test loss 1.447512, test error 50.30
# Epoch   400, train loss 1.038197, train error 34.70,  test loss 1.527325, test error 52.42
# Epoch   500, train loss 1.016300, train error 33.70,  test loss 1.576910, test error 51.72
# Epoch   600, train loss 0.990090, train error 32.38,  test loss 1.620870, test error 52.95
# Epoch   700, train loss 0.983077, train error 32.60,  test loss 1.634578, test error 52.38
# Epoch   800, train loss 0.972942, train error 32.82,  test loss 1.669215, test error 52.80
# Epoch   900, train loss 0.966277, train error 32.82,  test loss 1.697288, test error 52.92
# Training model with  26 hidden variables
# Epoch     0, train loss 2.149742, train error 80.72,  test loss 2.102379, test error 80.15
# Epoch   100, train loss 1.250030, train error 41.47,  test loss 1.397436, test error 51.85
# Epoch   200, train loss 1.107959, train error 36.95,  test loss 1.485855, test error 51.42
# Epoch   300, train loss 1.015602, train error 33.68,  test loss 1.584551, test error 52.03
# Epoch   400, train loss 0.975083, train error 33.18,  test loss 1.696742, test error 52.85
# Epoch   500, train loss 0.926641, train error 31.38,  test loss 1.767828, test error 53.28
# Epoch   600, train loss 0.915480, train error 31.38,  test loss 1.838899, test error 53.03
# Epoch   700, train loss 0.899422, train error 30.43,  test loss 1.899939, test error 54.12
# Epoch   800, train loss 0.898635, train error 30.68,  test loss 1.953005, test error 53.85
# Epoch   900, train loss 0.881542, train error 30.18,  test loss 2.007390, test error 54.45
# Training model with  30 hidden variables
# Epoch     0, train loss 2.167726, train error 79.68,  test loss 2.167635, test error 80.30
# Epoch   100, train loss 1.128502, train error 37.22,  test loss 1.339602, test error 48.83
# Epoch   200, train loss 0.940269, train error 30.62,  test loss 1.476602, test error 49.83
# Epoch   300, train loss 0.854501, train error 27.95,  test loss 1.680130, test error 52.35
# Epoch   400, train loss 0.805571, train error 26.07,  test loss 1.852890, test error 51.92
# Epoch   500, train loss 0.756422, train error 24.60,  test loss 2.035071, test error 53.53
# Epoch   600, train loss 0.722110, train error 24.10,  test loss 2.252189, test error 54.92
# Epoch   700, train loss 0.684984, train error 23.00,  test loss 2.415704, test error 55.62
# Epoch   800, train loss 0.679646, train error 22.12,  test loss 2.552563, test error 55.60
# Epoch   900, train loss 0.657813, train error 21.95,  test loss 2.694259, test error 56.17
# Training model with  35 hidden variables
# Epoch     0, train loss 2.159963, train error 80.35,  test loss 2.134208, test error 78.88
# Epoch   100, train loss 1.011338, train error 32.90,  test loss 1.399093, test error 49.67
# Epoch   200, train loss 0.775775, train error 25.38,  test loss 1.670496, test error 51.55
# Epoch   300, train loss 0.671352, train error 22.03,  test loss 2.041702, test error 53.00
# Epoch   400, train loss 0.599553, train error 19.70,  test loss 2.394724, test error 54.88
# Epoch   500, train loss 0.544761, train error 18.68,  test loss 2.721440, test error 55.83
# Epoch   600, train loss 0.523144, train error 17.40,  test loss 2.997649, test error 55.53
# Epoch   700, train loss 0.479778, train error 16.00,  test loss 3.244745, test error 55.92
# Epoch   800, train loss 0.471497, train error 16.03,  test loss 3.547422, test error 56.88
# Epoch   900, train loss 0.444252, train error 15.75,  test loss 3.755303, test error 57.60
# Training model with  40 hidden variables
# Epoch     0, train loss 2.136538, train error 78.32,  test loss 2.122263, test error 79.30
# Epoch   100, train loss 0.902678, train error 29.22,  test loss 1.393481, test error 48.42
# Epoch   200, train loss 0.624081, train error 20.07,  test loss 1.893578, test error 52.33
# Epoch   300, train loss 0.473721, train error 15.72,  test loss 2.555736, test error 53.70
# Epoch   400, train loss 0.405484, train error 13.60,  test loss 3.309627, test error 55.95
# Epoch   500, train loss 0.356957, train error 12.50,  test loss 4.035234, test error 54.85
# Epoch   600, train loss 0.303491, train error 10.60,  test loss 4.850986, test error 56.97
# Epoch   700, train loss 0.265100, train error 9.68,  test loss 5.602336, test error 56.67
# Epoch   800, train loss 0.233158, train error 8.78,  test loss 6.379201, test error 57.60
# Epoch   900, train loss 0.397790, train error 13.85,  test loss 7.145152, test error 57.78
# Training model with  45 hidden variables
# Epoch     0, train loss 2.085748, train error 77.18,  test loss 2.046029, test error 77.60
# Epoch   100, train loss 0.811888, train error 25.60,  test loss 1.566485, test error 51.22
# Epoch   200, train loss 0.453542, train error 13.05,  test loss 2.394970, test error 53.78
# Epoch   300, train loss 0.314058, train error 9.93,  test loss 3.403533, test error 54.47
# Epoch   400, train loss 0.193076, train error 5.57,  test loss 4.622046, test error 55.92
# Epoch   500, train loss 0.128561, train error 3.85,  test loss 5.786061, test error 55.80
# Epoch   600, train loss 0.109397, train error 3.78,  test loss 7.035810, test error 56.00
# Epoch   700, train loss 0.011295, train error 0.00,  test loss 8.157485, test error 56.67
# Epoch   800, train loss 0.007332, train error 0.00,  test loss 8.823096, test error 56.65
# Epoch   900, train loss 0.005520, train error 0.00,  test loss 9.302627, test error 56.78
# Training model with  50 hidden variables
# Epoch     0, train loss 2.066656, train error 76.15,  test loss 2.012652, test error 74.90
# Epoch   100, train loss 0.704641, train error 22.28,  test loss 1.642651, test error 50.72
# Epoch   200, train loss 0.355061, train error 10.68,  test loss 2.881303, test error 54.28
# Epoch   300, train loss 0.178315, train error 4.72,  test loss 4.504081, test error 55.33
# Epoch   400, train loss 0.032664, train error 0.03,  test loss 6.188957, test error 56.08
# Epoch   500, train loss 0.014089, train error 0.00,  test loss 7.230394, test error 56.30
# Epoch   600, train loss 0.008733, train error 0.00,  test loss 7.924176, test error 56.38
# Epoch   700, train loss 0.006207, train error 0.00,  test loss 8.435482, test error 56.38
# Epoch   800, train loss 0.004765, train error 0.00,  test loss 8.857013, test error 56.35
# Epoch   900, train loss 0.003807, train error 0.00,  test loss 9.193101, test error 56.35
# Training model with  55 hidden variables
# Epoch     0, train loss 2.065536, train error 77.30,  test loss 2.006527, test error 76.72
# Epoch   100, train loss 0.590857, train error 17.62,  test loss 1.687466, test error 50.75
# Epoch   200, train loss 0.205914, train error 5.00,  test loss 3.232811, test error 54.72
# Epoch   300, train loss 0.035539, train error 0.00,  test loss 5.024273, test error 55.15
# Epoch   400, train loss 0.013583, train error 0.00,  test loss 6.039063, test error 55.62
# Epoch   500, train loss 0.008041, train error 0.00,  test loss 6.652067, test error 55.78
# Epoch   600, train loss 0.005599, train error 0.00,  test loss 7.095016, test error 55.67
# Epoch   700, train loss 0.004201, train error 0.00,  test loss 7.445107, test error 55.85
# Epoch   800, train loss 0.003331, train error 0.00,  test loss 7.721849, test error 55.83
# Epoch   900, train loss 0.002752, train error 0.00,  test loss 7.958768, test error 55.75
# Training model with  60 hidden variables
# Epoch     0, train loss 2.061158, train error 76.75,  test loss 1.988173, test error 75.32
# Epoch   100, train loss 0.541722, train error 16.03,  test loss 1.773622, test error 51.35
# Epoch   200, train loss 0.108936, train error 1.12,  test loss 3.347362, test error 54.42
# Epoch   300, train loss 0.020204, train error 0.00,  test loss 4.756877, test error 55.67
# Epoch   400, train loss 0.009803, train error 0.00,  test loss 5.493952, test error 55.95
# Epoch   500, train loss 0.006102, train error 0.00,  test loss 5.960643, test error 55.80
# Epoch   600, train loss 0.004393, train error 0.00,  test loss 6.311406, test error 55.67
# Epoch   700, train loss 0.003346, train error 0.00,  test loss 6.584560, test error 55.58
# Epoch   800, train loss 0.002688, train error 0.00,  test loss 6.813718, test error 55.65
# Epoch   900, train loss 0.002231, train error 0.00,  test loss 7.006448, test error 55.55
# Training model with  70 hidden variables
# Epoch     0, train loss 2.020546, train error 74.40,  test loss 1.952727, test error 74.93
# Epoch   100, train loss 0.386346, train error 10.35,  test loss 1.998181, test error 52.60
# Epoch   200, train loss 0.031699, train error 0.00,  test loss 3.612031, test error 54.05
# Epoch   300, train loss 0.010680, train error 0.00,  test loss 4.392776, test error 54.20
# Epoch   400, train loss 0.005935, train error 0.00,  test loss 4.827007, test error 54.25
# Epoch   500, train loss 0.003982, train error 0.00,  test loss 5.130807, test error 54.17
# Epoch   600, train loss 0.002950, train error 0.00,  test loss 5.357596, test error 54.05
# Epoch   700, train loss 0.002315, train error 0.00,  test loss 5.540323, test error 54.00
# Epoch   800, train loss 0.001892, train error 0.00,  test loss 5.693276, test error 54.10
# Epoch   900, train loss 0.001591, train error 0.00,  test loss 5.825560, test error 54.17
# Training model with  80 hidden variables
# Epoch     0, train loss 2.000968, train error 73.55,  test loss 1.934043, test error 74.70
# Epoch   100, train loss 0.242381, train error 4.80,  test loss 2.074383, test error 51.03
# Epoch   200, train loss 0.020545, train error 0.00,  test loss 3.448232, test error 52.85
# Epoch   300, train loss 0.008308, train error 0.00,  test loss 4.009317, test error 52.80
# Epoch   400, train loss 0.004845, train error 0.00,  test loss 4.345345, test error 53.03
# Epoch   500, train loss 0.003353, train error 0.00,  test loss 4.584441, test error 53.08
# Epoch   600, train loss 0.002523, train error 0.00,  test loss 4.766279, test error 53.05
# Epoch   700, train loss 0.001999, train error 0.00,  test loss 4.917426, test error 52.95
# Epoch   800, train loss 0.001645, train error 0.00,  test loss 5.043021, test error 52.95
# Epoch   900, train loss 0.001392, train error 0.00,  test loss 5.151395, test error 53.08
# Training model with  90 hidden variables
# Epoch     0, train loss 2.007539, train error 75.88,  test loss 1.927057, test error 74.38
# Epoch   100, train loss 0.152363, train error 1.40,  test loss 2.195288, test error 50.72
# Epoch   200, train loss 0.014913, train error 0.00,  test loss 3.309899, test error 50.35
# Epoch   300, train loss 0.006494, train error 0.00,  test loss 3.754214, test error 50.33
# Epoch   400, train loss 0.003963, train error 0.00,  test loss 4.031909, test error 50.53
# Epoch   500, train loss 0.002787, train error 0.00,  test loss 4.231821, test error 50.75
# Epoch   600, train loss 0.002122, train error 0.00,  test loss 4.386385, test error 50.85
# Epoch   700, train loss 0.001697, train error 0.00,  test loss 4.512255, test error 50.83
# Epoch   800, train loss 0.001406, train error 0.00,  test loss 4.619429, test error 50.83
# Epoch   900, train loss 0.001195, train error 0.00,  test loss 4.711945, test error 50.88
# Training model with 100 hidden variables
# Epoch     0, train loss 1.987303, train error 73.25,  test loss 1.931073, test error 74.05
# Epoch   100, train loss 0.102451, train error 0.35,  test loss 2.252753, test error 51.42
# Epoch   200, train loss 0.012709, train error 0.00,  test loss 3.134325, test error 51.10
# Epoch   300, train loss 0.005836, train error 0.00,  test loss 3.512879, test error 51.00
# Epoch   400, train loss 0.003632, train error 0.00,  test loss 3.748704, test error 50.95
# Epoch   500, train loss 0.002582, train error 0.00,  test loss 3.920546, test error 51.08
# Epoch   600, train loss 0.001974, train error 0.00,  test loss 4.054470, test error 51.15
# Epoch   700, train loss 0.001586, train error 0.00,  test loss 4.165469, test error 51.20
# Epoch   800, train loss 0.001317, train error 0.00,  test loss 4.258659, test error 51.03
# Epoch   900, train loss 0.001121, train error 0.00,  test loss 4.340860, test error 51.03
# Training model with 120 hidden variables
# Epoch     0, train loss 1.969378, train error 73.60,  test loss 1.909966, test error 74.07
# Epoch   100, train loss 0.049161, train error 0.00,  test loss 2.239009, test error 50.67
# Epoch   200, train loss 0.009438, train error 0.00,  test loss 2.848029, test error 50.78
# Epoch   300, train loss 0.004670, train error 0.00,  test loss 3.132696, test error 50.60
# Epoch   400, train loss 0.003001, train error 0.00,  test loss 3.312088, test error 50.65
# Epoch   500, train loss 0.002159, train error 0.00,  test loss 3.446424, test error 50.70
# Epoch   600, train loss 0.001669, train error 0.00,  test loss 3.551911, test error 50.75
# Epoch   700, train loss 0.001350, train error 0.00,  test loss 3.639732, test error 50.78
# Epoch   800, train loss 0.001127, train error 0.00,  test loss 3.714566, test error 50.85
# Epoch   900, train loss 0.000964, train error 0.00,  test loss 3.779650, test error 50.88
# Training model with 140 hidden variables
# Epoch     0, train loss 1.943819, train error 70.75,  test loss 1.899755, test error 73.65
# Epoch   100, train loss 0.035477, train error 0.00,  test loss 2.191635, test error 50.53
# Epoch   200, train loss 0.007973, train error 0.00,  test loss 2.651649, test error 50.45
# Epoch   300, train loss 0.004115, train error 0.00,  test loss 2.879344, test error 50.65
# Epoch   400, train loss 0.002688, train error 0.00,  test loss 3.029125, test error 50.58
# Epoch   500, train loss 0.001958, train error 0.00,  test loss 3.140729, test error 50.42
# Epoch   600, train loss 0.001524, train error 0.00,  test loss 3.228863, test error 50.40
# Epoch   700, train loss 0.001239, train error 0.00,  test loss 3.301932, test error 50.33
# Epoch   800, train loss 0.001038, train error 0.00,  test loss 3.364793, test error 50.40
# Epoch   900, train loss 0.000890, train error 0.00,  test loss 3.419885, test error 50.38
# Training model with 160 hidden variables
# Epoch     0, train loss 1.928925, train error 71.55,  test loss 1.861134, test error 72.53
# Epoch   100, train loss 0.027351, train error 0.00,  test loss 2.166498, test error 49.75
# Epoch   200, train loss 0.007001, train error 0.00,  test loss 2.575672, test error 49.38
# Epoch   300, train loss 0.003709, train error 0.00,  test loss 2.781866, test error 49.80
# Epoch   400, train loss 0.002440, train error 0.00,  test loss 2.916340, test error 49.55
# Epoch   500, train loss 0.001792, train error 0.00,  test loss 3.019120, test error 49.50
# Epoch   600, train loss 0.001401, train error 0.00,  test loss 3.101617, test error 49.70
# Epoch   700, train loss 0.001143, train error 0.00,  test loss 3.168700, test error 49.62
# Epoch   800, train loss 0.000960, train error 0.00,  test loss 3.226586, test error 49.72
# Epoch   900, train loss 0.000824, train error 0.00,  test loss 3.277824, test error 49.85
# Training model with 180 hidden variables
# Epoch     0, train loss 1.919869, train error 70.97,  test loss 1.854271, test error 71.90
# Epoch   100, train loss 0.025561, train error 0.00,  test loss 1.981484, test error 48.05
# Epoch   200, train loss 0.006773, train error 0.00,  test loss 2.315823, test error 48.17
# Epoch   300, train loss 0.003606, train error 0.00,  test loss 2.487380, test error 48.17
# Epoch   400, train loss 0.002384, train error 0.00,  test loss 2.602817, test error 48.12
# Epoch   500, train loss 0.001752, train error 0.00,  test loss 2.690287, test error 48.08
# Epoch   600, train loss 0.001370, train error 0.00,  test loss 2.759175, test error 48.25
# Epoch   700, train loss 0.001118, train error 0.00,  test loss 2.816504, test error 48.30
# Epoch   800, train loss 0.000940, train error 0.00,  test loss 2.866019, test error 48.30
# Epoch   900, train loss 0.000808, train error 0.00,  test loss 2.909421, test error 48.20
# Training model with 200 hidden variables
# Epoch     0, train loss 1.912439, train error 70.25,  test loss 1.805023, test error 69.82
# Epoch   100, train loss 0.021045, train error 0.00,  test loss 2.017566, test error 48.08
# Epoch   200, train loss 0.006058, train error 0.00,  test loss 2.329982, test error 48.17
# Epoch   300, train loss 0.003298, train error 0.00,  test loss 2.492866, test error 48.28
# Epoch   400, train loss 0.002203, train error 0.00,  test loss 2.602077, test error 47.92
# Epoch   500, train loss 0.001628, train error 0.00,  test loss 2.684831, test error 47.85
# Epoch   600, train loss 0.001279, train error 0.00,  test loss 2.750933, test error 47.80
# Epoch   700, train loss 0.001046, train error 0.00,  test loss 2.806666, test error 47.75
# Epoch   800, train loss 0.000881, train error 0.00,  test loss 2.854095, test error 47.80
# Epoch   900, train loss 0.000759, train error 0.00,  test loss 2.895962, test error 47.80
# Training model with 250 hidden variables
# Epoch     0, train loss 1.871017, train error 67.45,  test loss 1.805021, test error 70.30
# Epoch   100, train loss 0.016755, train error 0.00,  test loss 1.922161, test error 48.47
# Epoch   200, train loss 0.005283, train error 0.00,  test loss 2.170482, test error 47.83
# Epoch   300, train loss 0.002943, train error 0.00,  test loss 2.305015, test error 47.70
# Epoch   400, train loss 0.001990, train error 0.00,  test loss 2.398055, test error 47.60
# Epoch   500, train loss 0.001483, train error 0.00,  test loss 2.467726, test error 47.50
# Epoch   600, train loss 0.001171, train error 0.00,  test loss 2.524276, test error 47.55
# Epoch   700, train loss 0.000962, train error 0.00,  test loss 2.571165, test error 47.55
# Epoch   800, train loss 0.000813, train error 0.00,  test loss 2.611993, test error 47.55
# Epoch   900, train loss 0.000701, train error 0.00,  test loss 2.647352, test error 47.55
# Training model with 300 hidden variables
# Epoch     0, train loss 1.873582, train error 67.82,  test loss 1.794152, test error 70.00
# Epoch   100, train loss 0.014499, train error 0.00,  test loss 1.849872, test error 46.58
# Epoch   200, train loss 0.004834, train error 0.00,  test loss 2.068332, test error 46.65
# Epoch   300, train loss 0.002744, train error 0.00,  test loss 2.184155, test error 46.62
# Epoch   400, train loss 0.001869, train error 0.00,  test loss 2.266570, test error 46.62
# Epoch   500, train loss 0.001399, train error 0.00,  test loss 2.328951, test error 46.55
# Epoch   600, train loss 0.001109, train error 0.00,  test loss 2.378748, test error 46.67
# Epoch   700, train loss 0.000913, train error 0.00,  test loss 2.420882, test error 46.80
# Epoch   800, train loss 0.000773, train error 0.00,  test loss 2.457755, test error 46.75
# Epoch   900, train loss 0.000668, train error 0.00,  test loss 2.490207, test error 46.70
# Training model with 400 hidden variables
# Epoch     0, train loss 1.872716, train error 66.93,  test loss 1.806575, test error 69.65
# Epoch   100, train loss 0.011590, train error 0.00,  test loss 1.814340, test error 47.17
# Epoch   200, train loss 0.004130, train error 0.00,  test loss 1.995545, test error 46.85
# Epoch   300, train loss 0.002393, train error 0.00,  test loss 2.097289, test error 46.90
# Epoch   400, train loss 0.001649, train error 0.00,  test loss 2.166963, test error 46.95
# Epoch   500, train loss 0.001243, train error 0.00,  test loss 2.221939, test error 46.72
# Epoch   600, train loss 0.000990, train error 0.00,  test loss 2.265648, test error 46.62
# Epoch   700, train loss 0.000818, train error 0.00,  test loss 2.302402, test error 46.70
# Epoch   800, train loss 0.000694, train error 0.00,  test loss 2.334333, test error 46.62
# Epoch   900, train loss 0.000601, train error 0.00,  test loss 2.361822, test error 46.60

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
