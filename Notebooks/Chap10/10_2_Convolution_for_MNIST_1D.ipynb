# %% [markdown]
# <a href="https://colab.research.google.com/github/chohayden/csci-166/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-udb51l6q
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-udb51l6q
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=ca3be5f375906bf4250192719c71c90793b74d862c5bf8f9fc2072df47b97ef6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-n564zg9_/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(60, 10)
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.124160, train error 79.15,  val loss 2.133888, percent error 79.10
# Epoch     1, train loss 1.514289, train error 60.08,  val loss 1.522676, percent error 61.70
# Epoch     2, train loss 1.357623, train error 54.62,  val loss 1.363608, percent error 57.20
# Epoch     3, train loss 1.305072, train error 51.65,  val loss 1.313687, percent error 53.60
# Epoch     4, train loss 1.183329, train error 46.40,  val loss 1.212202, percent error 49.90
# Epoch     5, train loss 1.077326, train error 43.90,  val loss 1.106576, percent error 46.70
# Epoch     6, train loss 0.970370, train error 38.97,  val loss 0.996062, percent error 41.00
# Epoch     7, train loss 0.897578, train error 36.33,  val loss 0.933699, percent error 39.20
# Epoch     8, train loss 0.867856, train error 34.20,  val loss 0.929550, percent error 36.30
# Epoch     9, train loss 0.847200, train error 34.00,  val loss 0.906358, percent error 37.20
# Epoch    10, train loss 0.737566, train error 28.70,  val loss 0.779404, percent error 29.80
# Epoch    11, train loss 0.647700, train error 24.75,  val loss 0.725458, percent error 28.70
# Epoch    12, train loss 0.630936, train error 24.28,  val loss 0.711515, percent error 27.70
# Epoch    13, train loss 0.614955, train error 24.10,  val loss 0.727348, percent error 29.30
# Epoch    14, train loss 0.587072, train error 22.32,  val loss 0.705404, percent error 27.80
# Epoch    15, train loss 0.495770, train error 18.72,  val loss 0.600265, percent error 23.40
# Epoch    16, train loss 0.441344, train error 17.10,  val loss 0.585073, percent error 21.80
# Epoch    17, train loss 0.379538, train error 13.90,  val loss 0.515556, percent error 18.40
# Epoch    18, train loss 0.350476, train error 12.95,  val loss 0.498038, percent error 17.90
# Epoch    19, train loss 0.324808, train error 11.97,  val loss 0.465995, percent error 16.50
# Epoch    20, train loss 0.267258, train error 9.32,  val loss 0.413361, percent error 14.30
# Epoch    21, train loss 0.248804, train error 9.15,  val loss 0.413156, percent error 14.30
# Epoch    22, train loss 0.206777, train error 7.25,  val loss 0.378539, percent error 12.70
# Epoch    23, train loss 0.206292, train error 6.57,  val loss 0.369230, percent error 12.40
# Epoch    24, train loss 0.193058, train error 6.38,  val loss 0.363125, percent error 13.60
# Epoch    25, train loss 0.217798, train error 8.10,  val loss 0.396775, percent error 13.30
# Epoch    26, train loss 0.166759, train error 5.55,  val loss 0.341224, percent error 11.20
# Epoch    27, train loss 0.156150, train error 5.22,  val loss 0.366007, percent error 12.10
# Epoch    28, train loss 0.171394, train error 5.97,  val loss 0.366340, percent error 12.60
# Epoch    29, train loss 0.143364, train error 4.97,  val loss 0.358438, percent error 11.80
# Epoch    30, train loss 0.136590, train error 4.35,  val loss 0.349265, percent error 11.90
# Epoch    31, train loss 0.137265, train error 4.72,  val loss 0.351124, percent error 11.70
# Epoch    32, train loss 0.139134, train error 4.72,  val loss 0.347356, percent error 12.00
# Epoch    33, train loss 0.132225, train error 4.55,  val loss 0.337055, percent error 10.70
# Epoch    34, train loss 0.136342, train error 4.95,  val loss 0.352654, percent error 10.80
# Epoch    35, train loss 0.102902, train error 3.25,  val loss 0.335672, percent error 11.00
# Epoch    36, train loss 0.100454, train error 3.45,  val loss 0.341087, percent error 10.20
# Epoch    37, train loss 0.093431, train error 3.03,  val loss 0.343383, percent error 10.90
# Epoch    38, train loss 0.101983, train error 3.50,  val loss 0.341523, percent error 10.20
# Epoch    39, train loss 0.106444, train error 3.85,  val loss 0.349542, percent error 11.00
# Epoch    40, train loss 0.073737, train error 2.18,  val loss 0.324193, percent error 10.30
# Epoch    41, train loss 0.075227, train error 2.15,  val loss 0.321428, percent error 9.90
# Epoch    42, train loss 0.067063, train error 1.70,  val loss 0.318911, percent error 9.50
# Epoch    43, train loss 0.065100, train error 1.78,  val loss 0.326887, percent error 10.40
# Epoch    44, train loss 0.064822, train error 1.62,  val loss 0.330777, percent error 10.10
# Epoch    45, train loss 0.065068, train error 1.72,  val loss 0.333266, percent error 9.90
# Epoch    46, train loss 0.059566, train error 1.53,  val loss 0.330525, percent error 10.10
# Epoch    47, train loss 0.059490, train error 1.38,  val loss 0.328648, percent error 9.60
# Epoch    48, train loss 0.057992, train error 1.65,  val loss 0.339475, percent error 10.20
# Epoch    49, train loss 0.054171, train error 1.43,  val loss 0.335603, percent error 9.80
# Epoch    50, train loss 0.063205, train error 1.80,  val loss 0.347159, percent error 10.40
# Epoch    51, train loss 0.052874, train error 1.25,  val loss 0.331186, percent error 10.20
# Epoch    52, train loss 0.051493, train error 1.22,  val loss 0.335531, percent error 10.20
# Epoch    53, train loss 0.054748, train error 1.43,  val loss 0.344471, percent error 9.60
# Epoch    54, train loss 0.051348, train error 1.05,  val loss 0.344209, percent error 10.10
# Epoch    55, train loss 0.063052, train error 2.15,  val loss 0.362438, percent error 10.50
# Epoch    56, train loss 0.046518, train error 1.03,  val loss 0.350345, percent error 9.40
# Epoch    57, train loss 0.047730, train error 1.15,  val loss 0.346677, percent error 9.50
# Epoch    58, train loss 0.046411, train error 1.10,  val loss 0.343431, percent error 10.10
# Epoch    59, train loss 0.043765, train error 0.88,  val loss 0.353306, percent error 10.10
# Epoch    60, train loss 0.040406, train error 0.72,  val loss 0.348808, percent error 9.90
# Epoch    61, train loss 0.041983, train error 0.80,  val loss 0.344745, percent error 9.60
# Epoch    62, train loss 0.039252, train error 0.68,  val loss 0.349905, percent error 9.70
# Epoch    63, train loss 0.039952, train error 0.75,  val loss 0.353041, percent error 9.80
# Epoch    64, train loss 0.038064, train error 0.62,  val loss 0.351156, percent error 9.80
# Epoch    65, train loss 0.038023, train error 0.57,  val loss 0.351754, percent error 9.80
# Epoch    66, train loss 0.039654, train error 0.75,  val loss 0.357360, percent error 10.10
# Epoch    67, train loss 0.038046, train error 0.62,  val loss 0.348389, percent error 9.80
# Epoch    68, train loss 0.037069, train error 0.57,  val loss 0.358133, percent error 9.70
# Epoch    69, train loss 0.038439, train error 0.62,  val loss 0.361823, percent error 9.80
# Epoch    70, train loss 0.035906, train error 0.55,  val loss 0.356451, percent error 9.90
# Epoch    71, train loss 0.035185, train error 0.43,  val loss 0.353607, percent error 10.00
# Epoch    72, train loss 0.035994, train error 0.55,  val loss 0.363222, percent error 9.80
# Epoch    73, train loss 0.034826, train error 0.45,  val loss 0.357431, percent error 9.60
# Epoch    74, train loss 0.034597, train error 0.45,  val loss 0.364812, percent error 10.00
# Epoch    75, train loss 0.034240, train error 0.55,  val loss 0.358456, percent error 10.20
# Epoch    76, train loss 0.033394, train error 0.45,  val loss 0.362792, percent error 9.90
# Epoch    77, train loss 0.032963, train error 0.40,  val loss 0.365412, percent error 10.00
# Epoch    78, train loss 0.033264, train error 0.43,  val loss 0.360826, percent error 10.10
# Epoch    79, train loss 0.032901, train error 0.45,  val loss 0.368864, percent error 10.30
# Epoch    80, train loss 0.031977, train error 0.40,  val loss 0.366121, percent error 10.10
# Epoch    81, train loss 0.031649, train error 0.30,  val loss 0.367868, percent error 10.30
# Epoch    82, train loss 0.031473, train error 0.38,  val loss 0.366736, percent error 9.90
# Epoch    83, train loss 0.031066, train error 0.38,  val loss 0.369824, percent error 10.20
# Epoch    84, train loss 0.030931, train error 0.32,  val loss 0.368749, percent error 10.00
# Epoch    85, train loss 0.031104, train error 0.32,  val loss 0.369073, percent error 10.20
# Epoch    86, train loss 0.030741, train error 0.38,  val loss 0.370382, percent error 10.10
# Epoch    87, train loss 0.030665, train error 0.35,  val loss 0.370379, percent error 10.00
# Epoch    88, train loss 0.030183, train error 0.30,  val loss 0.369197, percent error 10.10
# Epoch    89, train loss 0.030909, train error 0.35,  val loss 0.373252, percent error 10.10
# Epoch    90, train loss 0.029835, train error 0.28,  val loss 0.369138, percent error 10.10
# Epoch    91, train loss 0.029684, train error 0.30,  val loss 0.371201, percent error 10.10
# Epoch    92, train loss 0.029665, train error 0.28,  val loss 0.370950, percent error 10.30
# Epoch    93, train loss 0.029486, train error 0.30,  val loss 0.371679, percent error 9.90
# Epoch    94, train loss 0.029447, train error 0.32,  val loss 0.375087, percent error 10.10
# Epoch    95, train loss 0.029579, train error 0.30,  val loss 0.373729, percent error 9.90
# Epoch    96, train loss 0.028879, train error 0.28,  val loss 0.374898, percent error 10.30
# Epoch    97, train loss 0.029629, train error 0.32,  val loss 0.373962, percent error 10.30
# Epoch    98, train loss 0.028841, train error 0.28,  val loss 0.374613, percent error 10.20
# Epoch    99, train loss 0.028527, train error 0.28,  val loss 0.377802, percent error 10.00
